# %%
from numpy.testing import verbose
from tiktoken import model
from langchain_core.prompts import *
import streamlit as st, pandas as pd, numpy as np 

from langchain.agents import create_agent
from langchain_core.tools import tool
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
from langchain_experimental.tools import PythonREPLTool

llm =ChatOpenAI(temperature=0.5, max_tokens=100)

agent = create_agent(
    model=llm, 
    tools=[PythonREPLTool()],
    verbose=True  
) 

response=agent.invoke({"messages" : [{"role":"user","content":"Hello, what is the cube root of 42875?"}]})
result=response['messages'][-1].content
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 16
#      12 from langchain_experimental.tools import PythonREPLTool
#      13
#      14 llm =ChatOpenAI(temperature=0.5, max_tokens=100)
#      15
# ---> 16 agent = create_agent(
#      17     model=llm,
#      18     tools=[PythonREPLTool()],
#      19     verbose=True
#
# TypeError: create_agent() got an unexpected keyword argument 'verbose'

# %%
response['messages'][-1].content
# Out:
# 'The cube root of 42875 is approximately 35.0.'
